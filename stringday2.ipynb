# %% [markdown]
# <a href="https://colab.research.google.com/github/mrsameerkhan06-cmyk/Python_Practice/blob/main/stringday2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#strings
str1 = "sameer khan"
str2 = "i study in phython"
str3= "i can code in phython"

str4 = "sameer khan \n this line in next line"
print(str4)

str5 = str1 + " " + str3
print(str5)
print(len(str5))  #spaces and other special charactoers are also invlved

#INDEXING
#SAMEER
#012345
CH= str1[0]
print(CH)
#ch = str[4] = "hero"  nott allowed item assimble


#SLICLING
bio = "i am sameer khan andd im a student at arya college"
print(bio[0:5])
print(bio[5:11])
print(bio[5:len(bio)])

#string functions
eee= "string writen by sameer"

#str.endswith()  check if the string ends with sameer
print(eee.endswith("sameer"))

#str.capitalize()  capatalise the string
print(eee.capitalize())


#str.replace it replaces string from old to neew
print(eee.replace("sameer", "sameer khan"))

#str.find  find/ search for the string
print(eee.find("i"))
# Out:
# sameer khan
#  this line in next line
# sameer khan i can code in phython
# 33
# s
# i am
# sameer
# sameer khan andd im a student at arya college
# True
# String writen by sameer
# string writen by sameer khan
# 3
