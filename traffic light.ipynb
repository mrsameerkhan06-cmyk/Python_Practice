# %% [markdown]
# <a href="https://colab.research.google.com/github/mrsameerkhan06-cmyk/Python_Practice/blob/main/traffic%20light.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#conditionl statements
#if-elif-else
light = input("enter the colour of light.. ")

if(light =="red"):
  print("STOP wait for signol")
elif(light == "yellow"):
  print("look annd go..")
else:
  print("go")
# Out:
# enter the colour of light.. yellow
# look annd go..
