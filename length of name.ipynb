# %% [markdown]
# <a href="https://colab.research.google.com/github/mrsameerkhan06-cmyk/Python_Practice/blob/main/length%20of%20name.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("enter your name  :")
print(name)
print(len(name))
# Out:
# enter your name  :sameer khan
# sameer khan
# 11
