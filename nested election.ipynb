# %% [markdown]
# <a href="https://colab.research.google.com/github/mrsameerkhan06-cmyk/Python_Practice/blob/main/nested%20election.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from itertools import count
age = int(input("enter your age..."))
country = input("enter your nation you belong ...")

if(age >=18):
  if(country =="india"):
    print("can vote in india")
  else:
    print("cant vote...")
# Out:
# enter your age...23
# enter your nation you belong ...india
# can vote in india
