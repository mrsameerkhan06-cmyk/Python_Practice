# %% [markdown]
# <a href="https://colab.research.google.com/github/mrsameerkhan06-cmyk/Python_Practice/blob/main/practise%20questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#write code to update alice marks to 90 and bobs marks ti 88 using dictionary
students={"alice": 85,
          "bob" : 90}
students['alice'] = 90
students['bob'] = 88

print(students)
# Out:
# {'alice': 90, 'bob': 88}

# %%
#given list of fruits in carton how many banna in the carton
collection = ["apple", "banana", "carot", "chery", "banana", "apple", "dragon fruit", "banana", "apple", "carot", "banana","apple","banana"]
print(collection.count("banana"))
# Out:
# 5

# %%
#check for the name if student name in attandace list or not
attandance = {
    "sameer": "student",
    "shabana": "student",
    "khan": "student",
    "hero": "student",
    "sami": "student",
    "surya": "student",
}

if(attandance.get("sameer")=="student"):
  print("name found")
# Out:
# name found
