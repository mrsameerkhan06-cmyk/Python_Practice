# %% [markdown]
# <a href="https://colab.research.google.com/github/mrsameerkhan06-cmyk/Python_Practice/blob/main/practise%20questions%20in%20function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 #function
 #block of statement that performs a specific task

 def cal_sum(a, b):  #parameters
  sum = a + b
  print(sum)
  return sum;

cal_sum(595, -594)  #function call
cal_sum(1, 3)
def print_hello():
  print("hello")

print_hello()
# Out:
# 1
# 4
# hello

# %%
#avg of three num
def cal_avg(A, B, C):
  sum = A + B + C
  AVG = sum / 3
  print(AVG)
  return AVG

cal_avg(1, 2, 3)
# Out:
# 2.0
# 2.0

# %%
def calc_pro(a=1, b=1):  #default prameter
  print(a * b)
  return a * b

calc_pro(1,)
# Out:
# 1
# 1

# %%
#wap to print len of list
def lenth(a=[]):
  print(len(a))
  return len(a)

w=[1, 2, 3, 4, 4, "sameer"]
lenth(w)
# Out:
# 6

# %%
hero = ["sameer", "sami", "khann", "heroes"]
def print_list(list):
  for item in list:
    print(item, end=" ")
    return print(item)


  print_list(hero)
  print(4)
