# %% [markdown]
# <a href="https://colab.research.google.com/github/mrsameerkhan06-cmyk/Python_Practice/blob/main/election%20age%20verification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = float(input("enter your age  :"))
if(age < 18):
  print("cant vote and drive ...")
elif(age >= 18):
  print("can vote & drive ...")
# Out:
# enter your age  :99
# can vote & drive ...
