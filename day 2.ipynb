# %% [markdown]
# <a href="https://colab.research.google.com/github/mrsameerkhan06-cmyk/Python_Practice/blob/main/day%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ast import And
print("sameer is my name ....")
print("my age is 23")

print(" my name is sameer khan", "my age is 23..") #single line

#VARIABLES
#variables is name given to memory location in program (int, string, float, double, BOOLEAN , NONE etc)
name = "sameer khan"
price = 23.00
age = 23
print("name is ",name,"age is", age, "age  in float is", price)

#rules for variables
# identifeiers can be combinetion of lowercase letters digits
#2 an identifeirs can not start with digit so while variables1 is valid and 1variable not
#3we cant specal symbols like!@#$%&
#4 ident=tifers can be any length'


#*** IS POWER OPERATOR
num = 24
num += 2
price(num)


vali=True
vali2=False
print("AND operator", vali and vali2 )
print("or operator :", vali or vali2)
# Out:
# sameer is my name ....
# my age is 23
#  my name is sameer khan my age is 23..
# name is  sameer khan age is 23 age  in float is 23.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_744/91057862.py in <cell line: 0>()
#      22 num = 24
#      23 num += 2
# ---> 24 price(num)
#      25
#      26
#
# TypeError: 'float' object is not callable
