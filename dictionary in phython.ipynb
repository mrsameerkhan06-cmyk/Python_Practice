# %% [markdown]
# <a href="https://colab.research.google.com/github/mrsameerkhan06-cmyk/Python_Practice/blob/main/dictionary%20in%20phython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from re import sub
#dictionary in phython
#stores data values in key:value pairs
students = {
    "name" : "sameer",
    "sub" : "phyhton",
    "age": 33,
}

print(students)

#they are unordered , mutable/ changeable & dont alllow duplicate keys
print(students["name"])
students["name"] = "sameer khan"
print(students)


null_dict= {}
null_dict["name"] = "arya college of engg."
print(null_dict)

student2={
    "name" :input("enter your name in capital only"),
    "roll . no" : input("enter your roll no in capital only.."),
    "SUB" : {
        "DSA" : input("enter your DSA marks : "),
        "phython" : input("enter your PHYTHON marks : "),
        "applitude" : input("enter your APPLITUDE marks : "),
    }
}

print(student2)
#METHODS
#dict.keys()  returns keys in dict
#print(student2.keys())
#print(len(student2.keys()))

#dict,values  return values in dict
#print(student2.values)

#dict.items() returns (key, values ) as tuple
#print(student2.items())

#dict.get  returns values
#student["name"]  if not exxists error
#student.get("name")  #no error returns none if not exixsts

#dict.update  inserts new keys
#student2.update("city" : "jaipur")  also we can change older value to overwrite
# Out:
# {'name': 'sameer', 'sub': 'phyhton', 'age': 33}
# sameer
# {'name': 'sameer khan', 'sub': 'phyhton', 'age': 33}
# {'name': 'arya college of engg.'}
# enter your name in capital onlys
# enter your roll no in capital only..s
# enter your DSA marks : 1
# enter your PHYTHON marks : 1
# enter your APPLITUDE marks : 1
# {'name': 's', 'roll . no': 's', 'SUB': {'DSA': '1', 'phython': '1', 'applitude': '1'}}
# dict_items([('name', 's'), ('roll . no', 's'), ('SUB', {'DSA': '1', 'phython': '1', 'applitude': '1'})])
